# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров:-площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Изучение-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров: площадь, цена, число комнат, высота потолков.</a></span><ul class="toc-item"><li><span><a href="#Площадь" data-toc-modified-id="Площадь-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Площадь</a></span></li><li><span><a href="#Цена" data-toc-modified-id="Цена-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Цена</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Число комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Высота потолков</a></span></li></ul></li><li><span><a href="#Время-продажи-квартиры" data-toc-modified-id="Время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Время продажи квартиры</a></span></li><li><span><a href="#Удаление-редких-и-выбивающихся-значений." data-toc-modified-id="Удаление-редких-и-выбивающихся-значений.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Удаление редких и выбивающихся значений.</a></span></li><li><span><a href="#Факторы-влияющие-на-стоимость-квартиры" data-toc-modified-id="Факторы-влияющие-на-стоимость-квартиры-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Факторы влияющие на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Цена---площадь" data-toc-modified-id="Цена---площадь-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Цена - площадь</a></span></li><li><span><a href="#Цена---число-комнат" data-toc-modified-id="Цена---число-комнат-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Цена - число комнат</a></span></li><li><span><a href="#Цена----удаленность-от-центра" data-toc-modified-id="Цена----удаленность-от-центра-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Цена -  удаленность от центра</a></span></li><li><span><a href="#Цена---этаж" data-toc-modified-id="Цена---этаж-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Цена - этаж</a></span></li><li><span><a href="#Цена---год-продажи" data-toc-modified-id="Цена---год-продажи-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Цена - год продажи</a></span></li><li><span><a href="#Цена---месяц-продажи" data-toc-modified-id="Цена---месяц-продажи-4.4.6"><span class="toc-item-num">4.4.6&nbsp;&nbsp;</span>Цена - месяц продажи</a></span></li><li><span><a href="#Цена---день-продажи" data-toc-modified-id="Цена---день-продажи-4.4.7"><span class="toc-item-num">4.4.7&nbsp;&nbsp;</span>Цена - день продажи</a></span></li><li><span><a href="#Цена---местоположнение" data-toc-modified-id="Цена---местоположнение-4.4.8"><span class="toc-item-num">4.4.8&nbsp;&nbsp;</span>Цена - местоположнение</a></span></li></ul></li><li><span><a href="#Факторы-влияющие-на-стоимость-квартиры-в-центре" data-toc-modified-id="Факторы-влияющие-на-стоимость-квартиры-в-центре-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Факторы влияющие на стоимость квартиры в центре</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# Предоставлены данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
#
# **Цели исследования:**
# * Выяснить факторы больше всего влияющие на стоимость квартиры.
# * Изучить время продажи квартиры.
# * Выяснить отличаются ли факторы влияния в центре от общих выводов по всему городу**.
#
# **Описание данных:**
#
# * `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# * `balcony` — число балконов
# * `ceiling_height` — высота потолков (м)
# * `Centers_nearest` — расстояние до центра города (м)
# * `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# * `first_day_exposition`— дата публикации
# * `floor — этаж`
# * `floors_total` — всего этажей в доме
# * `is_apartment` — апартаменты (булев тип)
# * `kitchen_area` — площадь кухни в квадратных метрах (м²)
# * `last_price` — цена на момент снятия с публикации
# * `living_area` — жилая площадь в квадратных метрах (м²)
# * `locality_name` — название населённого пункта
# * `open_plan` — свободная планировка (булев тип)
# * `parks_around3000` — число парков в радиусе 3 км
# * `parks_neares`t — расстояние до ближайшего парка (м)
# * `ponds_around3000` — число водоёмов в радиусе 3 км
# * `ponds_nearest` — расстояние до ближайшего водоёма (м)
# * `rooms` — число комнат
# * `studio` — квартира-студия (булев тип)
# * `total_area` — площадь квартиры в квадратных метрах (м²)
# * `total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)
df = pd.read_csv(r'C:/Users/Home/datasets/real_estate_data.csv', sep = '\t')
df.head()
# Out:
#    total_images    last_price  total_area first_day_exposition  rooms  \
# 0            20 13,000,000.00      108.00  2019-03-07T00:00:00      3
# 1             7  3,350,000.00       40.40  2018-12-04T00:00:00      1
# 2            10  5,196,000.00       56.00  2015-08-20T00:00:00      2
# 3             0 64,900,000.00      159.00  2015-07-24T00:00:00      3
# 4             2 10,000,000.00      100.00  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70         16.00        51.00      8          NaN  ...
# 1             NaN         11.00        18.60      1          NaN  ...
# 2             NaN          5.00        34.30      4          NaN  ...
# 3             NaN         14.00          NaN      9          NaN  ...
# 4            3.03         14.00        32.00     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
df.describe()
# Out:
#        total_images     last_price  total_area     rooms  ceiling_height  \
# count     23,699.00      23,699.00   23,699.00 23,699.00       14,504.00
# mean           9.86   6,541,548.77       60.35      2.07            2.77
# std            5.68  10,887,013.27       35.65      1.08            1.26
# min            0.00      12,190.00       12.00      0.00            1.00
# 25%            6.00   3,400,000.00       40.00      1.00            2.52
# 50%            9.00   4,650,000.00       52.00      2.00            2.65
# 75%           14.00   6,800,000.00       69.90      3.00            2.80
# max           50.00 763,000,000.00      900.00     19.00          100.00
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count     23,613.00    21,796.00 23,699.00     21,421.00 12,180.00
# mean          10.67        34.46      5.89         10.57      1.15
# std            6.60        22.03      4.89          5.91      1.07
# ...

# %% [markdown]
# **Вывод**
#
# Таблица, состоит из 23699 строк и 22 колонок:
#
# В датасете высокий процент пропущенных значений; явные дубликаты отсутствуют; сожержит 2 логических значения, 14 вещественных, 3 целочисленных и 3 смешанных.
#
# Произведем предобработку данных:
#
# Удалим строки с долей пропусков менее 1%, заполним пропуски уместными значениями, заменим тип данных в `days_exposition` на datetime, `is_apartment` на буллев тип, заменим вещественный тип данных на целочисленный, где это уместно.

# %% [markdown]
# ## Предобработка данных

# %%
miss_value=pd.DataFrame(df.isna().mean()).reset_index()
miss_value.set_axis(['column_name', 'missing_value'], axis = 'columns', inplace = True)
miss_value.sort_values(by='missing_value', ascending=False).style.format({'missing_value': '{:,.2%}'.format})
# Out:
# <style type="text/css">
# </style>
# <table id="T_c4b7c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >column_name</th>
#       <th class="col_heading level0 col1" >missing_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4b7c_level0_row0" class="row_heading level0 row0" >9</th>
#       <td id="T_c4b7c_row0_col0" class="data row0 col0" >is_apartment</td>
#       <td id="T_c4b7c_row0_col1" class="data row0 col1" >88.29%</td>
#     </tr>
#     <tr>
#       <th id="T_c4b7c_level0_row1" class="row_heading level0 row1" >18</th>
#       <td id="T_c4b7c_row1_col0" class="data row1 col0" >parks_nearest</td>
#       <td id="T_c4b7c_row1_col1" class="data row1 col1" >65.91%</td>
#     </tr>
#     <tr>
#       <th id="T_c4b7c_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_c4b7c_row2_col0" class="data row2 col0" >ponds_nearest</td>
# ...

# %%
df=df.dropna(subset=['locality_name','floors_total'])#удалим пропуски менее процента

# %% [markdown]
# Апартаменты довольно редкий тип недвижимости в РФ. Заполним пропуски `is_apartment` нулями, т.к. скорее всего пользователи не считали нужным запольнять данное поле, не зная что такое апартаменты или считая что у них не апартаменты по умолчанию. Заменим на буллев тип данных.

# %%
df['is_apartment']=df['is_apartment'].fillna(0).astype('bool')

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y%m%dT%H:%M:%S')
#переведем тип данных в колонке first_day_exposition в формат даты

# %%
df['ponds_around3000']=df['ponds_around3000'].fillna(0)
df['parks_around3000']=df['parks_around3000'].fillna(0)
#Наличие парков и прудов
#В столбцах ponds_around3000 и parks_around3000 пропущенны значения соотвевуют 
#пропущенным значениям в столбцах ponds_around3000 и parks_around3000.

# %%
df['balcony']=df['balcony'].fillna(0)#если человек не указал число балконов — скорее всего, их нет

# %%
df['airports_nearest'] = df['airports_nearest'].fillna(-1)
df['cityCenters_nearest'] = df['cityCenters_nearest'].fillna(-1)
df['parks_nearest'] = df['parks_nearest'].fillna(-1)
df['ponds_nearest'] = df['ponds_nearest'].fillna(-1)
df['days_exposition'] = df['days_exposition'].fillna(-1).astype('int')
#Пропуски в столбцах заменим на нетипичные значения и будем учитывать в дальнейших рассчётах.

# %%
distance_med=df.groupby('locality_name')['airports_nearest'].median()
for locality_name in distance_med.index:
    df.loc[(df['airports_nearest'].isna()) & (df['locality_name'] == locality_name), 'airports_nearest'] = distance_med.loc[locality_name]
#Расстояние до аэропорта заполним медианными значениями по locality_name

# %%
df.loc[df['studio'] == 1, 'kitchen_area'] = 0
kitchen_med=df.groupby('locality_name')['kitchen_area'].median()
for locality_name in kitchen_med.index:
    df.loc[(df['kitchen_area'].isna()) & (df['locality_name'] == locality_name), 'kitchen_area'] = kitchen_med.loc[locality_name]
df=df.dropna(subset=['kitchen_area'])
# Площадь кухни, для студий заполним нулями, оставшиеся - медианным значением по locality_name

# %%
living_med = df.groupby('rooms')['living_area'].median()
for rooms_number in living_med.index:
    df.loc[(df['rooms'] == rooms_number), 'living_area'] = df.loc[(df['rooms'] == rooms_number),'living_area'].fillna(living_med[rooms_number])
#Число комнат, заполним медианным значением в зависимости от living_area

# %%
df['ceiling_height']=df['ceiling_height'].fillna(value=df['ceiling_height'].mode()[0])
#Высота потолков, заменим на модальное значение

# %%
for col in ['last_price', 'floors_total', 'balcony', 'parks_around3000', 'parks_nearest', 'ponds_nearest', 'ponds_around3000', 'airports_nearest', 'cityCenters_nearest']:
    df[col]=df[col].astype('int')#Заменим тип данных на целочисленный везде, кроме значения площадей и высоты потолков

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23547 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23547 non-null  int64
#  1   last_price            23547 non-null  int32
#  2   total_area            23547 non-null  float64
#  3   first_day_exposition  23547 non-null  datetime64[ns]
#  4   rooms                 23547 non-null  int64
#  5   ceiling_height        23547 non-null  float64
#  6   floors_total          23547 non-null  int32
#  7   living_area           23547 non-null  float64
#  8   floor                 23547 non-null  int64
#  9   is_apartment          23547 non-null  bool
#  10  studio                23547 non-null  bool
#  11  open_plan             23547 non-null  bool
#  12  kitchen_area          23547 non-null  float64
#  13  balcony               23547 non-null  int32
#  14  locality_name         23547 non-null  object
# ...

# %% [markdown]
# **Вывод**
#
# Обнаружили и обработали пропуски в датасете. Пропущенные данные скорее всего появились вследствие технической ошибки, либо пользователи не заполняли столбцы, как в случае с балконами или столбом `is_apartment`. Заменили типы данных.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
#Добавим столбец с ценой за квадратный метр
df['price_per_meter'] = df['last_price']/df['total_area']
df['price_per_meter']
# Out:
# 0       120,370.37
# 1        82,920.79
# 2        92,785.71
# 3       408,176.10
# 4       100,000.00
#            ...
# 23694    72,490.85
# 23695    52,542.37
# 23696    44,091.71
# 23697   149,511.40
# 23698    41,795.67
# Name: price_per_meter, Length: 23547, dtype: float64

# %%
def floor_groups(row):#Напишем функцию, которая будет определять этаж на котором расположена квартира (первый, последний, другой)
    if row['floor'] == 1:
        return 'первый этаж'
    elif row['floor'] == row['floors_total']:
        return 'последний этаж'
    return 'другой этаж'
df['floor_groups'] = df.apply(floor_groups, axis=1)

# %%
#Создадим столбцы соотношения жилой площади к общей площади и площади кухни к общей площади
df['ratio_area'] = df['living_area'] / df['total_area']
df['ratio_kitchen'] = df['kitchen_area'] / df['total_area']

# %%
#день недели, месяц и год публикации
df['publishing_day'] = df['first_day_exposition'].dt.weekday.astype('str').map({'0': 'ПН', '1': 'ВТ', '2': 'СР', '3': 'ЧТ', '4': 'ПТ', '5': 'СБ', '6': 'ВС'})
df['publishing_month'] = df['first_day_exposition'].dt.month.astype('str').map({'1': 'ЯНВ', '2': 'ФЕВ', '3': 'МАР', '4': 'АПР', '5': 'МАЙ', '6': 'ИЮН', '7': 'ИЮЛ', '8': 'АВГ', '9': 'СЕНТ', '10': 'ОКТ', '11': 'НОЯ', '12':'ДЕК'}) 
df['publishing_year'] = df['first_day_exposition'].dt.year

# %%
#Создадим столбцы соотношения жилой площади к общей площади и площади кухни к общей площади
df['ratio_area'] = df['living_area']/df['total_area']
df['ratio_kitchen'] = df['kitchen_area']/df['total_area']

# %%
df.sample(5)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 6740             12     5200000       73.00           2016-07-04      3
# 9781             19     7000000       79.50           2017-09-12      3
# 17133             6     5150000       59.30           2019-03-06      3
# 11444             0     9400000       94.00           2017-11-14      2
# 8180             20     7500000       46.00           2018-08-08      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 6740             2.70             9        44.00      1         False  ...
# 9781             2.50            25        43.30     23         False  ...
# 17133            2.50             5        46.10      2         False  ...
# 11444            2.50             5        30.60      5         False  ...
# 8180             2.85            22        17.60     20         False  ...
#
#        ponds_around3000  ponds_nearest  days_exposition  price_per_meter  \
# ...

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучение параметров: площадь, цена, число комнат, высота потолков.
# Построим гистаграммы для каждого параметра.

# %% [markdown]
# #### Площадь

# %%
df.hist('total_area', bins=100)
plt.xlabel('Площадь(кв.м)')
plt.show()#Изучим площадь

# %%
df['total_area'].describe()
# Out:
# count   23,547.00
# mean        60.32
# std         35.65
# min         12.00
# 25%         40.00
# 50%         52.00
# 75%         69.70
# max        900.00
# Name: total_area, dtype: float64

# %%
df.hist('total_area', bins=20, range = (0, 200))
plt.xlabel('Площадь(кв.м)')
plt.show();

# %% [markdown]
# Гистограмма соответсвует распределению Пуассона, среднее значение 35.65 кв.м. Минимальное значение 12м2, макс. 900м2. Присутствуют выбросы.

# %% [markdown]
# #### Цена

# %%
df['last_price'].describe()
# Out:
# count        23,547.00
# mean      6,543,206.40
# std      10,914,317.48
# min          12,190.00
# 25%       3,410,500.00
# 50%       4,650,000.00
# 75%       6,799,000.00
# max     763,000,000.00
# Name: last_price, dtype: float64

# %%
df.hist('last_price', bins=500, range=(0, 40000000))
plt.xlabel('Цена(млн.р)')
plt.show();

# %% [markdown]
# Гистограмма похожа распределению Пуассона. Минимальное значение 12190 не соответвует реальности, максимальное 763,000,000.00 в принципе имеет место быть. Медианное значение 6,543,206.40. Присутвуют выбросы.

# %% [markdown]
# #### Число комнат

# %%
df['rooms'].describe()
# Out:
# count   23,547.00
# mean         2.07
# std          1.08
# min          0.00
# 25%          1.00
# 50%          2.00
# 75%          3.00
# max         19.00
# Name: rooms, dtype: float64

# %%
df.hist('rooms',bins=30, range=(0, 7))
plt.xlabel('Количетсво комнат(шт.)')
plt.show();

# %%
df['rooms'].value_counts()
# Out:
# 1     7999
# 2     7890
# 3     5775
# 4     1172
# 5      324
# 0      193
# 6      104
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 15       1
# 19       1
# 16       1
# 12       1
# Name: rooms, dtype: int64

# %% [markdown]
# Больше всего 1,2,3-х комнатных квартир, присутвуют значения с нулем комнат. Присутвуют выбросы.

# %% [markdown]
# #### Высота потолков

# %%
df['ceiling_height'].describe()
# Out:
# count   23,547.00
# mean         2.67
# std          1.00
# min          1.00
# 25%          2.50
# 50%          2.50
# 75%          2.70
# max        100.00
# Name: ceiling_height, dtype: float64

# %%
df['ceiling_height'].value_counts()
# Out:
# 2.50    12584
# 2.60     1645
# 2.70     1571
# 3.00     1107
# 2.80      988
#         ...
# 5.00        1
# 2.20        1
# 4.15        1
# 3.93        1
# 3.59        1
# Name: ceiling_height, Length: 183, dtype: int64

# %%
df.hist('ceiling_height',bins=50, range=(2,5))
plt.xlabel('Высота потолков(м)')
plt.show();

# %% [markdown]
# Средная высота потолков 2.67 м2.,медиана - 2.50 м2. Присутвуют выбросы.

# %% [markdown]
# ### Время продажи квартиры

# %%
df['days_exposition'].describe()#Изучим данные
# Out:
# count   23,547.00
# mean       156.29
# std        213.59
# min         -1.00
# 25%         22.00
# 50%         73.00
# 75%        198.00
# max      1,580.00
# Name: days_exposition, dtype: float64

# %%
df.hist('days_exposition', bins=100, range=(-2,100))
plt.xlabel('Время продажи(дни)')
plt.ylabel('Количество квартир(шт.)')
plt.show();

# %%
df.hist('days_exposition', bins=40, range=(-2,100))
plt.xlabel('Время продажи(дни)')
plt.show();

# %% [markdown]
# Присутствуют пики на 45 и 60 днях. Медиана 73 дня. Среднее значение 156 дней.

# %%
df.boxplot('days_exposition')
plt.title('Время продажи')
plt.ylabel('Количество дней');

# %% [markdown]
# Выбросы начинаются от времени продажи больше 400 дней, при занчение больше 400 дней можно считать что продажа шла необычно долго. При значении меньше медианы(73 дня) можно считать, что продажа прошла быстро. Пики -  вероятнее всего день автоматического снятия объявления с площадки.

# %% [markdown]
# ### Удаление редких и выбивающихся значений.

# %%
df.boxplot(column='total_area', figsize=(15,2), vert=False,)
plt.title('Время продажи')
plt.xlabel('Количество дней');

# %%
df.drop(df[df['total_area'] > 101].index, inplace=True)#уберем выбросы больше 101 м2

# %%
df.hist('last_price', bins=500, range=(0, 40000000))
plt.title('Последняя цена')
plt.xlabel('')
plt.ylabel('Количество дней');

# %%
df.boxplot(column='last_price', figsize=(15,2), vert=False,);

# %%
df.drop(df[df['last_price'] > 10000000].index, inplace=True)#уберем выбросы больше 10000000

# %%
df.boxplot(column='rooms', figsize=(15,2), vert=False);

# %%
df.drop(df[df['rooms'] > 3].index, inplace=True)
df.drop(df[df['rooms'] == 0].index, inplace=True)#удалим выбросы, комнаты больше 3 и нулевые значения

# %%
plt.ylim(1,3)
df.boxplot(column='ceiling_height');

# %%
df.drop(df[df['ceiling_height'] > 3].index, inplace=True)
df.drop(df[df['ceiling_height'] < 2.25].index, inplace=True)#удалим выбросы, высота потолков 3 и меньше 2.25

# %%
df.boxplot(column='days_exposition', figsize=(15,2), vert=False)

plt.ylabel('Количесвто дней');

# %%
df.drop(df[df['days_exposition'] > 400].index, inplace=True)

# %% [markdown]
# ### Факторы влияющие на стоимость квартиры

# %% [markdown]
# #### Цена - площадь

# %%
#Посмотрим как влияет размер площади на цену квартиры
df.plot(y='last_price',x='total_area',kind='scatter', figsize=(15,5))
plt.title('Как размер площади влияет на цену квартиры');

# %%
print('Корреляция:', df['total_area'].corr(df['last_price']))
# Out:
# Корреляция: 0.6386482130406392

# %% [markdown]
# Чем больше площадь, тем больше цена. Линейно-положительная корреляция.

# %% [markdown]
# #### Цена - число комнат

# %%
print('Корреляция:', df['last_price'].corr(df['rooms']))
df.plot(x='rooms', y='last_price', kind='scatter', alpha=0.05)
plt.title('Зависимость цены от числа комнат', size=14)
plt.xlabel('Число комнат, комн.')
plt.ylabel('Цена, млн руб.')
plt.show()
# Out:
# Корреляция: 0.3907466828080102

# %% [markdown]
# Зависимость между ценой и числом комнат есть, но не очень сильная

# %% [markdown]
# #### Цена -  удаленность от центра

# %%
df.drop(df[df['cityCenters_nearest'] <0].index, inplace=True)

# %%
print(df['cityCenters_nearest'].corr(df['last_price']))
df.plot(x='cityCenters_nearest', y='last_price', kind='scatter', alpha=0.06)
plt.title('Зависимость цены от удалённости от центра')
plt.xlabel('Удалённость от центра, км')
plt.ylabel('Цена, млн руб.')
plt.show()
# Out:
# -0.29864028621158956

# %% [markdown]
# Прослеживается зависимость, чем дальше от центра тем меньше стоит квартира

# %% [markdown]
# #### Цена - этаж

# %%
price_and_floor_types = df.loc[:, ['floor_groups', 'last_price']]

price_and_floor_types_corr = price_and_floor_types.floor_groups.str.get_dummies(sep=' ').corrwith(price_and_floor_types.last_price)
price_and_floor_types_corr
# Out:
# другой       0.11
# первый      -0.10
# последний   -0.05
# этаж          NaN
# dtype: float64

# %% [markdown]
# На первом и последнем этаже квартиры незначительно дешевле

# %% [markdown]
# #### Цена - год продажи

# %%
df.pivot_table(index='publishing_year', values='last_price', aggfunc='median').plot();

# %% [markdown]
# В 2014 году рынок недвижимости рухнул. С 2017 года идет небольшой подъем

# %% [markdown]
# #### Цена - месяц продажи

# %%
df.pivot_table(index='publishing_month', values='last_price', aggfunc='median').plot();

# %% [markdown]
# Самые высокие цены в декабре, самые низкие летом

# %% [markdown]
# #### Цена - день продажи

# %%
df.pivot_table(index='publishing_day', values='last_price', aggfunc='median').plot();

# %% [markdown]
# Самые высокие цены в  среду и во вторник

# %% [markdown]
# #### Цена - местоположнение

# %% [markdown]
# Исследуем населенные пункты.

# %%
df['locality_name'] = df['locality_name'].str.lower()
df['locality_name'] = df['locality_name'].str.replace('ё', 'е')
df['locality_name'].value_counts()
# Out:
# санкт-петербург            10569
# поселок шушары               383
# поселок парголово            290
# пушкин                       285
# колпино                      278
# петергоф                     162
# красное село                 136
# сестрорецк                   128
# ломоносов                    100
# кронштадт                     76
# поселок металлострой          53
# поселок стрельна              35
# павловск                      29
# зеленогорск                   20
# поселок понтонный             19
# поселок саперный               5
# поселок песочный               4
# поселок молодежное             3
# поселок лисий нос              2
# поселок усть-ижора             2
# поселок белоостров             1
# поселок репино                 1
# поселок александровская        1
# Name: locality_name, dtype: int64

# %%
df.groupby('locality_name')['price_per_meter'].agg(['mean', 'count']).sort_values(by='count', ascending=False).head(10)
# Out:
#                         mean  count
# locality_name
# санкт-петербург   104,965.36  10569
# поселок шушары     78,367.58    383
# поселок парголово  90,294.74    290
# пушкин             99,815.31    285
# колпино            75,870.34    278
# петергоф           83,743.05    162
# красное село       72,599.95    136
# сестрорецк        101,192.15    128
# ломоносов          73,407.54    100
# кронштадт          79,646.54     76

# %% [markdown]
# Самая высокая стоимость квдратного метра в Питере, самая низкая в Кронштадте.

# %%
df.pivot_table(index='locality_name', values='price_per_meter', aggfunc='mean').sort_values(by='price_per_meter', ascending=False)
# Out:
#                          price_per_meter
# locality_name
# поселок лисий нос             113,728.35
# санкт-петербург               104,965.36
# сестрорецк                    101,192.15
# зеленогорск                   100,123.73
# пушкин                         99,815.31
# поселок репино                 92,727.27
# поселок парголово              90,294.74
# поселок стрельна               88,048.34
# петергоф                       83,743.05
# павловск                       81,224.22
# поселок песочный               79,726.84
# кронштадт                      79,646.54
# поселок шушары                 78,367.58
# колпино                        75,870.34
# поселок металлострой           75,268.59
# ломоносов                      73,407.54
# красное село                   72,599.95
# поселок понтонный              70,680.20
# поселок молодежное             68,928.91
# поселок белоостров             66,666.67
# поселок усть-ижора             65,935.67
# ...

# %% [markdown]
# По всем объявлениям самая высокая стоимость в Поселке Лисий нос, самая низкая в поселке Александровская

# %% [markdown]
# ### Факторы влияющие на стоимость квартиры в центре

# %% [markdown]
# Создадим столбец с расстоянием до центра в километрах: округлим до целых значений. Посчитаем среднюю цену для каждого километра. Построим график зависимости цены от удалённости от центра.

# %%
df['distance_to_center'] = (df['cityCenters_nearest']/1000).astype('int')

# %%
df['price_for_kilometer'] = (df['last_price']/df['cityCenters_nearest'])

# %%
spb = df.query('locality_name == "санкт-петербург"')

# %%
spb.pivot_table(index='distance_to_center', values='price_for_kilometer', aggfunc='mean').plot(y='price_for_kilometer', grid=True, figsize=(12,6), style='o-');

# %%
spb.pivot_table(index='distance_to_center', values='price_for_kilometer', aggfunc='mean')
# Out:
#                     price_for_kilometer
# distance_to_center
# 0                             10,673.54
# 1                              4,850.09
# 2                              2,779.12
# 3                              1,849.35
# 4                              1,493.01
# 5                              1,208.69
# 6                                955.53
# 7                                820.37
# 8                                661.64
# 9                                535.62
# 10                               476.85
# 11                               445.72
# 12                               415.17
# 13                               392.40
# 14                               352.49
# 15                               322.00
# 16                               295.02
# 17                               260.61
# 18                               252.26
# 19                               240.09
# 20                               307.04
# 21                               223.63
# ...

# %% [markdown]
# Цена резко растет при расстоянии центры около  8-10 км, дальше идёт в том числе спад и длительная стагнация стоимости.

# %% [markdown]
# Выделим сегмент квартир в центре

# %%
center = df.query('distance_to_center <= 8')

# %%
for column in center[['total_area','last_price','rooms','ceiling_height','days_exposition']]:
    range_max = center[column].max()
    range_min = center[column].min()
    center[column].hist(bins=30, range=(range_min,range_max))
    plt.title(column, fontsize=15)
    plt.show()
    print('Среднее значение:',center[column].mean())
# Out:
# Среднее значение: 55.22726161369197
# Среднее значение: 6289165.846577018
# Среднее значение: 1.952322738386308
# Среднее значение: 2.642646699266507
# Среднее значение: 99.17848410757946

# %% [markdown]
# Площадь квартир в центре с среднем больше, цена выше, время продажи в целом такое же.

# %%
table_center = center[['last_price','ceiling_height','rooms','total_area','floor']]
pd.plotting.scatter_matrix(table_center, figsize=(12,12));

# %%
table_center.corr()
# Out:
#                 last_price  ceiling_height  rooms  total_area  floor
# last_price            1.00            0.17   0.41        0.70   0.12
# ceiling_height        0.17            1.00   0.09        0.15  -0.06
# rooms                 0.41            0.09   1.00        0.77  -0.16
# total_area            0.70            0.15   0.77        1.00  -0.06
# floor                 0.12           -0.06  -0.16       -0.06   1.00

# %%
df[['last_price', 'ceiling_height','rooms','total_area', 'floor']].corr()
# Out:
#                 last_price  ceiling_height  rooms  total_area  floor
# last_price            1.00            0.27   0.49        0.75   0.12
# ceiling_height        0.27            1.00  -0.01        0.16   0.03
# rooms                 0.49           -0.01   1.00        0.80  -0.15
# total_area            0.75            0.16   0.80        1.00   0.01
# floor                 0.12            0.03  -0.15        0.01   1.00

# %% [markdown]
# В центре цена чуть меньше зависит от  числа комнат, общей площади и высоты потолков.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В данном исследование мы изучили архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет, что впоследствии поможет определять рыночную стоимость объектов недвижимости.
#
# * заполнили пропущенные данные в исследуемых столбцах
# * установили связь между разными параметрами и построили графики
# * избавились от редких и выбивающихся значений
#
# Установили что:
# * дороже всего кадратный метр стоит в Санкт-Петербурге и в посёлке Лисий Нос, дешевле всего квартиры в Поселок александровская и Кронштадте;
# * квартиры на первом и последнем этаже дешевле, чем на любом другом;
# * цены на квартиры как в центре Санкт-Петербурга, так и в целом зависят в первую очередь от общей площади, а также от жилой площади и площади кухни, в меньшей степени от количества комнат. Остальные факторы оказывают на ценообразование меньшее влияние.
